# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('train.csv')

# %%
#Checking which columns have NaN data
pd.isnull(train_data).sum() > 0
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [raw]
# Now it's known that for some passengers Age, Cabin, and Embarked are missing.

# %%
#what percent of people survived
np.count_nonzero(train_data.Survived)/ float(len(train_data))
# Out:
# 0.3838383838383838

# %% [raw]
# According to most estimates 31.6% of people survived, so this data set contains more survivors

# %%
#Going to check what percent of survivors were male/female
amount_survived = float(np.count_nonzero(train_data.Survived))
male_survived = len([passenger for index, passenger in train_data.iterrows() if passenger.Sex == 'Male' and passenger.Survived])

male_surv_perc = male_surv/amount_survived

# %%
percs = [male_surv_perc, 1-male_surv_perc]
labels = ['Male', 'Female']
fig = plt.figure()
fig.suptitle('Distribution of Survivors by Gender', fontsize=14, fontweight='bold')
plt.pie(percs, explode=None,labels = labels)
plt.show()

# %% [raw]
# Now let's analyze class effects on survival rate

# %%
import matplotlib.pyplot as plt


first_class_survivors = len([passenger for id, passenger in train_data.iterrows() if passenger.Survived and passenger.Pclass == 1])/(amount_survived)
second_class_survivors = len([passenger for id, passenger in train_data.iterrows() if passenger.Survived and passenger.Pclass == 2])/(amount_survived)
third_class_survicors = len([passenger for id, passenger in train_data.iterrows() if passenger.Survived and passenger.Pclass == 3])/(amount_survived)


percs = [first_class_survivors, second_class_survivors, third_class_survicors]
labels = ['1st Class', '2nd Class', '3rd Class']
fig = plt.figure()
fig.suptitle('Distribution of Survivors by Class', fontsize=14, fontweight='bold')
plt.pie(percs, explode=None,labels = labels)
plt.show()
